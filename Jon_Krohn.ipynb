# %% [markdown]
# <a href="https://colab.research.google.com/github/iypc-team/NewNotebook/blob/master/Jon_Krohn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile ColorUtil.py
class ColorUtil:
    def __init__():
        self.C = C
    
    WHITE = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
    BACKGROUND = '\033[7m'
    LITE = '\033[90m'
    RED = '\033[91m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    BLUE = '\033[94m'
    HEADER = '\033[95m'

C = ColorUtil
print(f'{C.WHITE}{C.UNDERLINE}OK')
# Out:
# OK

# %%
from __future__ import absolute_import, division, print_function
from IPython.display import clear_output
try:
    import ColorUtil
    from ColorUtil import C
    print(f'{C.GREEN}')
except: pass
# %pip install tensorflow
# %pip install gitpython
clear_output()

# %%
import git, glob, os, pathlib, sys
import tensorflow as tf
from os.path import *
from pathlib import Path
from git import Remote, Repo

cwdPath = Path.cwd()
print(cwdPath)
repoList = ['https://github.com/jonkrohn/ML-foundations', 
           'https://github.com/jonkrohn/DLTFpT', 
           'https://github.com/jonkrohn/tf2', 
           'https://github.com/jonkrohn/pytorch', 
           'https://github.com/jonkrohn/TensorFlow-LiveLessons', 
           'https://github.com/jonkrohn/SLM-Lab', 
           'https://github.com/jonkrohn/docker-stacks', 
           'https://github.com/jonkrohn/keras-attention',
           'https://github.com/jonkrohn/study-group']

print(f'{C.GREEN}OK')
# Out:
# /content
# OK

# %%
count = 0
for repo in repoList:
    count += 1
    repoPath = join(repo)
    localPath = join(Path.home(), basename(repo))
    if not exists(localPath):
        print(f'{C.RED}{localPath}{C.WHITE} Does not exist')
        # _ = 
        Repo.clone_from(repoPath, localPath)
    elif exists(localPath):
        print(f'{C.GREEN}{localPath}{C.WHITE} exists')
# Out:
# /root/ML-foundations exists
# /root/DLTFpT exists
# /root/tf2 exists
# /root/pytorch exists
# /root/TensorFlow-LiveLessons exists
# /root/SLM-Lab exists
# /root/docker-stacks exists
# /root/keras-attention exists
# /root/study-group exists

# %%
# %cd
allFiles = glob.glob('**', recursive=True)
allFilesDict = {}

fileCount = 0
print(f'{C.BLUE}{Path.cwd()}')
for fil in sorted(allFiles):
    realPath = realpath(fil)
    fullPath = Path(realpath(fil))
    if isdir(fullPath) and not realPath.__contains__('__pycache__'):
        print(f'\n{C.BLUE}{fullPath}')
    elif isfile(fullPath):
        fileCount += 1
        allFilesDict[fileCount] = fullPath
        print(f'{C.WHITE}{fileCount}. {fullPath}')
# Out:
# /root
# /root
#
# /root/DLTFpT
# 1. /root/DLTFpT/Dockerfile
# 2. /root/DLTFpT/LICENSE
# 3. /root/DLTFpT/README.md
#
# /root/DLTFpT/installation
# 4. /root/DLTFpT/installation/README.md
# 5. /root/DLTFpT/installation/let_jovyan_write.sh
# 6. /root/DLTFpT/installation/macOS.md
# 7. /root/DLTFpT/installation/windows_simple.md
# 8. /root/DLTFpT/installation/windows_step_by_step.md
#
# /root/DLTFpT/notebooks
# 9. /root/DLTFpT/notebooks/alexnet_in_tensorflow.ipynb
# 10. /root/DLTFpT/notebooks/bidirectional_lstm_sentiment_classifier.ipynb
# 11. /root/DLTFpT/notebooks/cartpole_dqn.ipynb
# 12. /root/DLTFpT/notebooks/clean_gutenberg_model.w2v
# 13. /root/DLTFpT/notebooks/clean_gutenberg_tsne.csv
# 14. /root/DLTFpT/notebooks/conv_lstm_stack_sentiment_classifier.ipynb
# 15. /root/DLTFpT/notebooks/convolutional_sentiment_classifier.ipynb
# 16. /root/DLTFpT/notebooks/creating_word_vectors_with_word2vec.ipynb
# 17. /root/DLTFpT/notebooks/cross_entropy_cost.ipynb
# 18. /root/DLTFpT/notebooks/deep_net_in_pytorch.ipynb
# 19. /root/DLTFpT/notebooks/deep_net_in_tensorflow.ipynb
# 20. /root/DLTFpT/notebooks/dense_sentiment_classifier.ipynb
# 21. /root/DLTFpT/notebooks/generative_adversarial_network.ipynb
# 22. /root/DLTFpT/notebooks/gru_sentiment_classifier.ipynb
# 23. /root/DLTFpT/notebooks/intermediate_net_in_tensorflow.ipynb
# 24. /root/DLTFpT/notebooks/lenet_in_tensorflow.ipynb
# 25. /root/DLTFpT/notebooks/lenet_in_tensorflow_for_fashion_MNIST.ipynb
#
# /root/DLTFpT/notebooks/logs
#
# /root/DLTFpT/notebooks/logs/regression_baseline
#
# /root/DLTFpT/notebooks/logs/regression_baseline/train
# 26. /root/DLTFpT/notebooks/logs/regression_baseline/train/events.out.tfevents.1566596715.202bbfafd1f0.35.1880.v2
# 27. /root/DLTFpT/notebooks/logs/regression_baseline/train/events.out.tfevents.1566596715.202bbfafd1f0.profile-empty
#
# /root/DLTFpT/notebooks/logs/regression_baseline/train/plugins
#
# /root/DLTFpT/notebooks/logs/regression_baseline/train/plugins/profile
#
# /root/DLTFpT/notebooks/logs/regression_baseline/train/plugins/profile/2019-08-23_21-45-15
# 28. /root/DLTFpT/notebooks/logs/regression_baseline/train/plugins/profile/2019-08-23_21-45-15/local.trace
#
# /root/DLTFpT/notebooks/logs/regression_baseline/validation
# 29. /root/DLTFpT/notebooks/logs/regression_baseline/validation/events.out.tfevents.1566596717.202bbfafd1f0.35.2365.v2
#
# /root/DLTFpT/notebooks/logs/regression_drop50
#
# /root/DLTFpT/notebooks/logs/regression_drop50/train
# 30. /root/DLTFpT/notebooks/logs/regression_drop50/train/events.out.tfevents.1566596787.202bbfafd1f0.68.1880.v2
# 31. /root/DLTFpT/notebooks/logs/regression_drop50/train/events.out.tfevents.1566596787.202bbfafd1f0.profile-empty
#
# /root/DLTFpT/notebooks/logs/regression_drop50/train/plugins
#
# /root/DLTFpT/notebooks/logs/regression_drop50/train/plugins/profile
#
# /root/DLTFpT/notebooks/logs/regression_drop50/train/plugins/profile/2019-08-23_21-46-27
# 32. /root/DLTFpT/notebooks/logs/regression_drop50/train/plugins/profile/2019-08-23_21-46-27/local.trace
#
# /root/DLTFpT/notebooks/logs/regression_drop50/validation
# 33. /root/DLTFpT/notebooks/logs/regression_drop50/validation/events.out.tfevents.1566596788.202bbfafd1f0.68.2365.v2
# 34. /root/DLTFpT/notebooks/lstm_sentiment_classifier.ipynb
# 35. /root/DLTFpT/notebooks/measuring_speed_of_learning.ipynb
# 36. /root/DLTFpT/notebooks/multi_convnet_sentiment_classifier.ipynb
# 37. /root/DLTFpT/notebooks/natural_language_preprocessing.ipynb
# 38. /root/DLTFpT/notebooks/object_detection.ipynb
# 39. /root/DLTFpT/notebooks/oboe-with-book.jpg
#
# /root/DLTFpT/notebooks/old
# 40. /root/DLTFpT/notebooks/old/shallow-net-in-pytorch.ipynb
# 41. /root/DLTFpT/notebooks/old/shallow-net-in-tf.ipynb
# 42. /root/DLTFpT/notebooks/quadratic_cost.ipynb
# 43. /root/DLTFpT/notebooks/raw_gutenberg_model.w2v
# 44. /root/DLTFpT/notebooks/raw_gutenberg_tsne.csv
# 45. /root/DLTFpT/notebooks/regression_in_tensorflow.ipynb
# 46. /root/DLTFpT/notebooks/regression_in_tensorflow_with_tensorboard.ipynb
# 47. /root/DLTFpT/notebooks/rnn_sentiment_classifier.ipynb
# 48. /root/DLTFpT/notebooks/sequence_generation.ipynb
# 49. /root/DLTFpT/notebooks/shallow_net_in_pytorch.ipynb
# 50. /root/DLTFpT/notebooks/shallow_net_in_tensorflow.ipynb
# 51. /root/DLTFpT/notebooks/sigmoid_function.ipynb
# 52. /root/DLTFpT/notebooks/softmax_demo.ipynb
# 53. /root/DLTFpT/notebooks/stacked_bi_lstm_sentiment_classifier.ipynb
# 54. /root/DLTFpT/notebooks/transfer_learning_in_tensorflow.ipynb
# 55. /root/DLTFpT/notebooks/vggnet_in_tensorflow.ipynb
# 56. /root/DLTFpT/notebooks/weight_initialization.ipynb
# 57. /root/DLTFpT/rundocker.bat
# 58. /root/DLTFpT/rundocker.sh
#
# /root/ML-foundations
# 59. /root/ML-foundations/Dockerfile
# 60. /root/ML-foundations/LICENSE
# 61. /root/ML-foundations/README.md
#
# /root/ML-foundations/img
# 62. /root/ML-foundations/img/Oboe.jpg
#
# /root/ML-foundations/installation
# 63. /root/ML-foundations/installation/README.md
# 64. /root/ML-foundations/installation/let_jovyan_write.sh
#
# /root/ML-foundations/notebooks
# 65. /root/ML-foundations/notebooks/1-intro-to-linear-algebra.ipynb
# 66. /root/ML-foundations/notebooks/2-linear-algebra-ii.ipynb
# 67. /root/ML-foundations/notebooks/3-calculus-i.ipynb
# 68. /root/ML-foundations/notebooks/4-calculus-ii.ipynb
# 69. /root/ML-foundations/notebooks/5-probability.ipynb
# 70. /root/ML-foundations/notebooks/6-statistics.ipynb
# 71. /root/ML-foundations/notebooks/7-algos-and-data-structures.ipynb
# 72. /root/ML-foundations/notebooks/8-optimization.ipynb
# 73. /root/ML-foundations/notebooks/batch-regression-gradient.ipynb
# 74. /root/ML-foundations/notebooks/regression-in-pytorch.ipynb
# 75. /root/ML-foundations/notebooks/single-point-regression-gradient.ipynb
#
# /root/SLM-Lab
# 76. /root/SLM-Lab/LICENSE
# 77. /root/SLM-Lab/README.md
#
# /root/SLM-Lab/bin
# 78. /root/SLM-Lab/bin/copy_config
# 79. /root/SLM-Lab/bin/setup
# 80. /root/SLM-Lab/bin/setup_macOS
# 81. /root/SLM-Lab/bin/setup_ubuntu
#
# /root/SLM-Lab/config
# 82. /root/SLM-Lab/config/example_default.json
# 83. /root/SLM-Lab/environment.yml
# 84. /root/SLM-Lab/main.py
# 85. /root/SLM-Lab/package.json
# 86. /root/SLM-Lab/setup.py
#
# /root/SLM-Lab/slm_lab
# 87. /root/SLM-Lab/slm_lab/__init__.py
#
# /root/SLM-Lab/slm_lab/agent
# 88. /root/SLM-Lab/slm_lab/agent/__init__.py
#
# /root/SLM-Lab/slm_lab/agent/algorithm
# 89. /root/SLM-Lab/slm_lab/agent/algorithm/__init__.py
# 90. /root/SLM-Lab/slm_lab/agent/algorithm/algorithm_util.py
# 91. /root/SLM-Lab/slm_lab/agent/algorithm/base.py
# 92. /root/SLM-Lab/slm_lab/agent/algorithm/dqn.py
# 93. /root/SLM-Lab/slm_lab/agent/algorithm/random.py
#
# /root/SLM-Lab/slm_lab/agent/memory
# 94. /root/SLM-Lab/slm_lab/agent/memory/__init__.py
# 95. /root/SLM-Lab/slm_lab/agent/memory/base.py
# 96. /root/SLM-Lab/slm_lab/agent/memory/replay.py
#
# /root/SLM-Lab/slm_lab/agent/net
# 97. /root/SLM-Lab/slm_lab/agent/net/__init__.py
# 98. /root/SLM-Lab/slm_lab/agent/net/convnet.py
# 99. /root/SLM-Lab/slm_lab/agent/net/feedforward.py
# 100. /root/SLM-Lab/slm_lab/agent/net/net_util.py
#
# /root/SLM-Lab/slm_lab/curriculum
# 101. /root/SLM-Lab/slm_lab/curriculum/__init__.py
#
# /root/SLM-Lab/slm_lab/env
# 102. /root/SLM-Lab/slm_lab/env/__init__.py
#
# /root/SLM-Lab/slm_lab/evolution
# 103. /root/SLM-Lab/slm_lab/evolution/__init__.py
#
# /root/SLM-Lab/slm_lab/experiment
# 104. /root/SLM-Lab/slm_lab/experiment/__init__.py
# 105. /root/SLM-Lab/slm_lab/experiment/analysis.py
# 106. /root/SLM-Lab/slm_lab/experiment/control.py
# 107. /root/SLM-Lab/slm_lab/experiment/fitness_std.json
# 108. /root/SLM-Lab/slm_lab/experiment/monitor.py
#
# /root/SLM-Lab/slm_lab/lib
# 109. /root/SLM-Lab/slm_lab/lib/__init__.py
# 110. /root/SLM-Lab/slm_lab/lib/logger.py
# 111. /root/SLM-Lab/slm_lab/lib/util.py
# 112. /root/SLM-Lab/slm_lab/lib/viz.py
#
# /root/SLM-Lab/slm_lab/notebook
# 113. /root/SLM-Lab/slm_lab/notebook/__init__.py
# 114. /root/SLM-Lab/slm_lab/notebook/intro_hydrogen.py
# 115. /root/SLM-Lab/slm_lab/notebook/intro_tf.py
# 116. /root/SLM-Lab/slm_lab/notebook/intro_unity.py
#
# /root/SLM-Lab/slm_lab/spec
# 117. /root/SLM-Lab/slm_lab/spec/__init__.py
# 118. /root/SLM-Lab/slm_lab/spec/base.json
# 119. /root/SLM-Lab/slm_lab/spec/demo.json
# 120. /root/SLM-Lab/slm_lab/spec/dqn.json
# 121. /root/SLM-Lab/slm_lab/spec/random.json
# 122. /root/SLM-Lab/slm_lab/spec/spec_util.py
#
# /root/SLM-Lab/slm_lab/teacher
# 123. /root/SLM-Lab/slm_lab/teacher/__init__.py
#
# /root/SLM-Lab/test
# 124. /root/SLM-Lab/test/__init__.py
#
# /root/SLM-Lab/test/agent
#
# /root/SLM-Lab/test/agent/memory
# 125. /root/SLM-Lab/test/agent/memory/test_memory.py
#
# /root/SLM-Lab/test/agent/net
# 126. /root/SLM-Lab/test/agent/net/test_data.py
# 127. /root/SLM-Lab/test/agent/net/test_nn.py
# 128. /root/SLM-Lab/test/conftest.py
#
# /root/SLM-Lab/test/experiment
# 129. /root/SLM-Lab/test/experiment/test_control.py
# 130. /root/SLM-Lab/test/experiment/test_monitor.py
#
# /root/SLM-Lab/test/fixture
#
# /root/SLM-Lab/test/fixture/common
#
# /root/SLM-Lab/test/fixture/common/util
# 131. /root/SLM-Lab/test/fixture/common/util/test_df.csv
# 132. /root/SLM-Lab/test/fixture/common/util/test_dict.json
# 133. /root/SLM-Lab/test/fixture/common/util/test_dict.yml
# 134. /root/SLM-Lab/test/fixture/common/util/test_str.txt
#
# /root/SLM-Lab/test/lib
# 135. /root/SLM-Lab/test/lib/test_logger.py
# 136. /root/SLM-Lab/test/lib/test_util.py
#
# /root/SLM-Lab/test/spec
# 137. /root/SLM-Lab/test/spec/test_spec.py
# 138. /root/SLM-Lab/test/spec/test_spec_util.py
# 139. /root/SLM-Lab/yarn.lock
#
# /root/TensorFlow-LiveLessons
# 140. /root/TensorFlow-LiveLessons/Dockerfile
# 141. /root/TensorFlow-LiveLessons/Dockerfile-gpu
# 142. /root/TensorFlow-LiveLessons/LICENSE
# 143. /root/TensorFlow-LiveLessons/README.md
# 144. /root/TensorFlow-LiveLessons/book.jpg
#
# /root/TensorFlow-LiveLessons/installation
# 145. /root/TensorFlow-LiveLessons/installation/README.md
# 146. /root/TensorFlow-LiveLessons/installation/conda_TensorFlow_install.md
#
# /root/TensorFlow-LiveLessons/installation/docker-stack-scripts
# 147. /root/TensorFlow-LiveLessons/installation/docker-stack-scripts/Jupyter-docker-stacks-license.md
# 148. /root/TensorFlow-LiveLessons/installation/docker-stack-scripts/jupyter_notebook_config.py
# 149. /root/TensorFlow-LiveLessons/installation/docker-stack-scripts/start-notebook.sh
# 150. /root/TensorFlow-LiveLessons/installation/docker-stack-scripts/start-singleuser.sh
# 151. /root/TensorFlow-LiveLessons/installation/docker-stack-scripts/start.sh
# 152. /root/TensorFlow-LiveLessons/installation/let_jovyan_write.sh
# 153. /root/TensorFlow-LiveLessons/installation/miscellaneous_notes.md
# 154. /root/TensorFlow-LiveLessons/installation/simple_Windows_Anaconda_install.md
# 155. /root/TensorFlow-LiveLessons/installation/step_by_step_GCP_install.md
# 156. /root/TensorFlow-LiveLessons/installation/step_by_step_MacOSX_install.md
# 157. /root/TensorFlow-LiveLessons/installation/step_by_step_Windows_Docker_install.md
# 158. /root/TensorFlow-LiveLessons/installation/windows_TF_GPU.md
#
# /root/TensorFlow-LiveLessons/notebooks
# 159. /root/TensorFlow-LiveLessons/notebooks/alexnet_in_keras.ipynb
# 160. /root/TensorFlow-LiveLessons/notebooks/bidirectional_lstm.ipynb
# 161. /root/TensorFlow-LiveLessons/notebooks/cartpole_dqn.ipynb
# 162. /root/TensorFlow-LiveLessons/notebooks/convolutional_sentiment_classifier.ipynb
# 163. /root/TensorFlow-LiveLessons/notebooks/creating_word_vectors_with_word2vec.ipynb
# 164. /root/TensorFlow-LiveLessons/notebooks/cross_entropy_cost.ipynb
# 165. /root/TensorFlow-LiveLessons/notebooks/deep_net_in_keras.ipynb
# 166. /root/TensorFlow-LiveLessons/notebooks/dense_sentiment_classifier.ipynb
# 167. /root/TensorFlow-LiveLessons/notebooks/first_tensorflow_graphs.ipynb
# 168. /root/TensorFlow-LiveLessons/notebooks/first_tensorflow_neurons.ipynb
# 169. /root/TensorFlow-LiveLessons/notebooks/generative_adversarial_network.ipynb
# 170. /root/TensorFlow-LiveLessons/notebooks/gru_in_keras.ipynb
# 171. /root/TensorFlow-LiveLessons/notebooks/intermediate_net_in_keras.ipynb
# 172. /root/TensorFlow-LiveLessons/notebooks/intermediate_net_in_tensorflow.ipynb
# 173. /root/TensorFlow-LiveLessons/notebooks/intro_to_tensorflow_times_a_million.ipynb
# 174. /root/TensorFlow-LiveLessons/notebooks/lenet_in_keras.ipynb
# 175. /root/TensorFlow-LiveLessons/notebooks/lenet_in_tensorflow.ipynb
#
# /root/TensorFlow-LiveLessons/notebooks/live_training
# 176. /root/TensorFlow-LiveLessons/notebooks/live_training/convolutional_sentiment_classifier_LT.ipynb
# 177. /root/TensorFlow-LiveLessons/notebooks/live_training/deep_net_in_keras_LT.ipynb
# 178. /root/TensorFlow-LiveLessons/notebooks/live_training/deep_net_in_tensorflow_LT.ipynb
# 179. /root/TensorFlow-LiveLessons/notebooks/live_training/dense_sentiment_classifier_LT.ipynb
# 180. /root/TensorFlow-LiveLessons/notebooks/live_training/first_tensorflow_graphs_LT.ipynb
# 181. /root/TensorFlow-LiveLessons/notebooks/live_training/first_tensorflow_neurons_LT.ipynb
# 182. /root/TensorFlow-LiveLessons/notebooks/live_training/multi_convnet_architectures_LT.ipynb
# 183. /root/TensorFlow-LiveLessons/notebooks/live_training/natural_language_preprocessing_best_practices_LT.ipynb
# 184. /root/TensorFlow-LiveLessons/notebooks/live_training/point_by_point_intro_to_tensorflow_LT.ipynb
# 185. /root/TensorFlow-LiveLessons/notebooks/live_training/rnn_in_keras_LT.ipynb
# 186. /root/TensorFlow-LiveLessons/notebooks/live_training/shallow_net_in_keras_LT.ipynb
# 187. /root/TensorFlow-LiveLessons/notebooks/live_training/tensor-fied_intro_to_tensorflow_LT.ipynb
# 188. /root/TensorFlow-LiveLessons/notebooks/live_training/vanilla_lstm_in_keras_LT.ipynb
# 189. /root/TensorFlow-LiveLessons/notebooks/multi_convnet_architectures.ipynb
# 190. /root/TensorFlow-LiveLessons/notebooks/natural_language_preprocessing_best_practices.ipynb
# 191. /root/TensorFlow-LiveLessons/notebooks/point_by_point_intro_to_tensorflow.ipynb
# 192. /root/TensorFlow-LiveLessons/notebooks/rnn_in_keras.ipynb
# 193. /root/TensorFlow-LiveLessons/notebooks/shallow_net_in_keras.ipynb
# 194. /root/TensorFlow-LiveLessons/notebooks/sigmoid_function.ipynb
# 195. /root/TensorFlow-LiveLessons/notebooks/softmax_demo.ipynb
# 196. /root/TensorFlow-LiveLessons/notebooks/stacked_bidirectional_lstm.ipynb
# 197. /root/TensorFlow-LiveLessons/notebooks/tensor-fied_intro_to_tensorflow.ipynb
# 198. /root/TensorFlow-LiveLessons/notebooks/vanilla_lstm_in_keras.ipynb
# 199. /root/TensorFlow-LiveLessons/notebooks/vggnet_in_keras.ipynb
# 200. /root/TensorFlow-LiveLessons/notebooks/ye_olde_conv_lstm_stackeroo.ipynb
#
# /root/docker-stacks
# 201. /root/docker-stacks/LICENSE.md
# 202. /root/docker-stacks/Makefile
# 203. /root/docker-stacks/README.md
#
# /root/docker-stacks/all-spark-notebook
# 204. /root/docker-stacks/all-spark-notebook/Dockerfile
# 205. /root/docker-stacks/all-spark-notebook/README.md
#
# /root/docker-stacks/all-spark-notebook/hooks
# 206. /root/docker-stacks/all-spark-notebook/hooks/post_push
# 207. /root/docker-stacks/all-spark-notebook/kernel.json
#
# /root/docker-stacks/base-notebook
# 208. /root/docker-stacks/base-notebook/Dockerfile
# 209. /root/docker-stacks/base-notebook/Dockerfile.ppc64le
# 210. /root/docker-stacks/base-notebook/Dockerfile.ppc64le.patch
# 211. /root/docker-stacks/base-notebook/README.md
#
# /root/docker-stacks/base-notebook/hooks
# 212. /root/docker-stacks/base-notebook/hooks/post_push
# 213. /root/docker-stacks/base-notebook/jupyter_notebook_config.py
# 214. /root/docker-stacks/base-notebook/start-notebook.sh
# 215. /root/docker-stacks/base-notebook/start-singleuser.sh
# 216. /root/docker-stacks/base-notebook/start.sh
#
# /root/docker-stacks/datascience-notebook
# 217. /root/docker-stacks/datascience-notebook/Dockerfile
# 218. /root/docker-stacks/datascience-notebook/README.md
#
# /root/docker-stacks/datascience-notebook/hooks
# 219. /root/docker-stacks/datascience-notebook/hooks/post_push
#
# /root/docker-stacks/examples
#
# /root/docker-stacks/examples/docker-compose
# 220. /root/docker-stacks/examples/docker-compose/README.md
#
# /root/docker-stacks/examples/docker-compose/bin
# 221. /root/docker-stacks/examples/docker-compose/bin/letsencrypt.sh
# 222. /root/docker-stacks/examples/docker-compose/bin/sl-dns.sh
# 223. /root/docker-stacks/examples/docker-compose/bin/softlayer.sh
# 224. /root/docker-stacks/examples/docker-compose/bin/vbox.sh
#
# /root/docker-stacks/examples/docker-compose/notebook
# 225. /root/docker-stacks/examples/docker-compose/notebook/Dockerfile
# 226. /root/docker-stacks/examples/docker-compose/notebook/README.md
# 227. /root/docker-stacks/examples/docker-compose/notebook/build.sh
# 228. /root/docker-stacks/examples/docker-compose/notebook/down.sh
# 229. /root/docker-stacks/examples/docker-compose/notebook/env.sh
# 230. /root/docker-stacks/examples/docker-compose/notebook/letsencrypt-notebook.yml
# 231. /root/docker-stacks/examples/docker-compose/notebook/notebook.yml
# 232. /root/docker-stacks/examples/docker-compose/notebook/secure-notebook.yml
# 233. /root/docker-stacks/examples/docker-compose/notebook/up.sh
#
# /root/docker-stacks/examples/make-deploy
# 234. /root/docker-stacks/examples/make-deploy/Dockerfile
# 235. /root/docker-stacks/examples/make-deploy/Makefile
# 236. /root/docker-stacks/examples/make-deploy/README.md
# 237. /root/docker-stacks/examples/make-deploy/letsencrypt.makefile
# 238. /root/docker-stacks/examples/make-deploy/self-signed.makefile
# 239. /root/docker-stacks/examples/make-deploy/softlayer.makefile
# 240. /root/docker-stacks/examples/make-deploy/virtualbox.makefile
#
# /root/docker-stacks/internal
# 241. /root/docker-stacks/internal/README.md
#
# /root/docker-stacks/internal/docker-stacks-webhook
# 242. /root/docker-stacks/internal/docker-stacks-webhook/conda_requirements.txt
# 243. /root/docker-stacks/internal/docker-stacks-webhook/docker-stacks-webhook.ipynb
# 244. /root/docker-stacks/internal/docker-stacks-webhook/manifest.yml
# 245. /root/docker-stacks/internal/docker-stacks-webhook/requirements.txt
# 246. /root/docker-stacks/internal/docker-stacks-webhook/runtime.txt
# 247. /root/docker-stacks/internal/inherit-diagram.png
#
# /root/docker-stacks/minimal-notebook
# 248. /root/docker-stacks/minimal-notebook/Dockerfile
# 249. /root/docker-stacks/minimal-notebook/README.md
#
# /root/docker-stacks/minimal-notebook/hooks
# 250. /root/docker-stacks/minimal-notebook/hooks/post_push
#
# /root/docker-stacks/pyspark-notebook
# 251. /root/docker-stacks/pyspark-notebook/Dockerfile
# 252. /root/docker-stacks/pyspark-notebook/README.md
#
# /root/docker-stacks/pyspark-notebook/hooks
# 253. /root/docker-stacks/pyspark-notebook/hooks/post_push
#
# /root/docker-stacks/r-notebook
# 254. /root/docker-stacks/r-notebook/Dockerfile
# 255. /root/docker-stacks/r-notebook/README.md
#
# /root/docker-stacks/r-notebook/hooks
# 256. /root/docker-stacks/r-notebook/hooks/post_push
#
# /root/docker-stacks/scipy-notebook
# 257. /root/docker-stacks/scipy-notebook/Dockerfile
# 258. /root/docker-stacks/scipy-notebook/README.md
#
# /root/docker-stacks/scipy-notebook/hooks
# 259. /root/docker-stacks/scipy-notebook/hooks/post_push
#
# /root/docker-stacks/tensorflow-notebook
# 260. /root/docker-stacks/tensorflow-notebook/Dockerfile
# 261. /root/docker-stacks/tensorflow-notebook/README.md
#
# /root/docker-stacks/tensorflow-notebook/hooks
# 262. /root/docker-stacks/tensorflow-notebook/hooks/post_push
#
# /root/keras-attention
# 263. /root/keras-attention/LICENSE
# 264. /root/keras-attention/README.md
# 265. /root/keras-attention/__init__.py
#
# /root/keras-attention/data
# 266. /root/keras-attention/data/generate.py
# 267. /root/keras-attention/data/reader.py
#
# /root/keras-attention/models
# 268. /root/keras-attention/models/NMT.py
# 269. /root/keras-attention/models/__init__.py
# 270. /root/keras-attention/models/custom_recurrents.py
# 271. /root/keras-attention/requirements-gpu.txt
# 272. /root/keras-attention/requirements.txt
# 273. /root/keras-attention/run.py
#
# /root/keras-attention/utils
# 274. /root/keras-attention/utils/__init__.py
# 275. /root/keras-attention/utils/examples.py
# 276. /root/keras-attention/utils/examples.txt
# 277. /root/keras-attention/utils/metrics.py
# 278. /root/keras-attention/visualize.py
#
# /root/keras-attention/weights
# 279. /root/keras-attention/weights/NMT.49-0.01.hdf5
#
# /root/pytorch
# 280. /root/pytorch/LICENSE
# 281. /root/pytorch/README.md
#
# /root/pytorch/notebooks
# 282. /root/pytorch/notebooks/deep_net_in_pytorch.ipynb
# 283. /root/pytorch/notebooks/deep_net_in_pytorch_DEMO.ipynb
# 284. /root/pytorch/notebooks/shallow_net_in_pytorch.ipynb
# 285. /root/pytorch/notebooks/shallow_net_in_pytorch_DEMO.ipynb
#
# /root/study-group
# 286. /root/study-group/LICENSE
# 287. /root/study-group/README.md
#
# /root/study-group/demos-for-talks
# 288. /root/study-group/demos-for-talks/AlexNet.ipynb
# 289. /root/study-group/demos-for-talks/AlexNet.py
# 290. /root/study-group/demos-for-talks/Keras_MNIST_ConvNet.ipynb
# 291. /root/study-group/demos-for-talks/VGGNet.ipynb
# 292. /root/study-group/demos-for-talks/simple_dnn.ipynb
# 293. /root/study-group/demos-for-talks/simple_dnn.py
#
# /root/study-group/neural-networks-and-deep-learning
# 294. /root/study-group/neural-networks-and-deep-learning/README.md
#
# /root/study-group/neural-networks-and-deep-learning/data
# 295. /root/study-group/neural-networks-and-deep-learning/data/mnist.pkl.gz
#
# /root/study-group/neural-networks-and-deep-learning/fig
# 296. /root/study-group/neural-networks-and-deep-learning/fig/backprop_magnitude_nabla.png
# 297. /root/study-group/neural-networks-and-deep-learning/fig/backprop_magnitude_nabla.py
# 298. /root/study-group/neural-networks-and-deep-learning/fig/data_1000.json
# 299. /root/study-group/neural-networks-and-deep-learning/fig/digits.png
# 300. /root/study-group/neural-networks-and-deep-learning/fig/digits_separate.png
# 301. /root/study-group/neural-networks-and-deep-learning/fig/false_minima.png
# 302. /root/study-group/neural-networks-and-deep-learning/fig/false_minima.py
# 303. /root/study-group/neural-networks-and-deep-learning/fig/generate_gradient.py
# 304. /root/study-group/neural-networks-and-deep-learning/fig/initial_gradient.json
# 305. /root/study-group/neural-networks-and-deep-learning/fig/misleading_gradient.png
# 306. /root/study-group/neural-networks-and-deep-learning/fig/misleading_gradient.py
# 307. /root/study-group/neural-networks-and-deep-learning/fig/misleading_gradient_contours.png
# 308. /root/study-group/neural-networks-and-deep-learning/fig/misleading_gradient_contours.py
# 309. /root/study-group/neural-networks-and-deep-learning/fig/mnist.py
# 310. /root/study-group/neural-networks-and-deep-learning/fig/mnist_100_digits.png
# 311. /root/study-group/neural-networks-and-deep-learning/fig/mnist_2_and_1.png
# 312. /root/study-group/neural-networks-and-deep-learning/fig/mnist_complete_zero.png
# 313. /root/study-group/neural-networks-and-deep-learning/fig/mnist_first_digit.png
# 314. /root/study-group/neural-networks-and-deep-learning/fig/mnist_other_features.png
# 315. /root/study-group/neural-networks-and-deep-learning/fig/mnist_really_bad_images.png
# 316. /root/study-group/neural-networks-and-deep-learning/fig/mnist_top_left_feature.png
# 317. /root/study-group/neural-networks-and-deep-learning/fig/more_data.json
# 318. /root/study-group/neural-networks-and-deep-learning/fig/more_data.png
# 319. /root/study-group/neural-networks-and-deep-learning/fig/more_data.py
# 320. /root/study-group/neural-networks-and-deep-learning/fig/more_data_5.png
# 321. /root/study-group/neural-networks-and-deep-learning/fig/more_data_comparison.png
# 322. /root/study-group/neural-networks-and-deep-learning/fig/more_data_log.png
# 323. /root/study-group/neural-networks-and-deep-learning/fig/more_data_rotated_5.png
# 324. /root/study-group/neural-networks-and-deep-learning/fig/more_data_svm.json
# 325. /root/study-group/neural-networks-and-deep-learning/fig/multiple_eta.json
# 326. /root/study-group/neural-networks-and-deep-learning/fig/multiple_eta.png
# 327. /root/study-group/neural-networks-and-deep-learning/fig/multiple_eta.py
# 328. /root/study-group/neural-networks-and-deep-learning/fig/norms_during_training_2_layers.json
# 329. /root/study-group/neural-networks-and-deep-learning/fig/norms_during_training_3_layers.json
# 330. /root/study-group/neural-networks-and-deep-learning/fig/norms_during_training_4_layers.json
# 331. /root/study-group/neural-networks-and-deep-learning/fig/overfitting.json
# 332. /root/study-group/neural-networks-and-deep-learning/fig/overfitting.py
# 333. /root/study-group/neural-networks-and-deep-learning/fig/overfitting1.png
# 334. /root/study-group/neural-networks-and-deep-learning/fig/overfitting2.png
# 335. /root/study-group/neural-networks-and-deep-learning/fig/overfitting3.png
# 336. /root/study-group/neural-networks-and-deep-learning/fig/overfitting4.png
# 337. /root/study-group/neural-networks-and-deep-learning/fig/overfitting_full.json
# 338. /root/study-group/neural-networks-and-deep-learning/fig/overfitting_full.png
# 339. /root/study-group/neural-networks-and-deep-learning/fig/pca_hard_data.png
# 340. /root/study-group/neural-networks-and-deep-learning/fig/pca_hard_data_fit.png
# 341. /root/study-group/neural-networks-and-deep-learning/fig/pca_limitations.py
# 342. /root/study-group/neural-networks-and-deep-learning/fig/regularized.json
# 343. /root/study-group/neural-networks-and-deep-learning/fig/regularized1.png
# 344. /root/study-group/neural-networks-and-deep-learning/fig/regularized2.png
# 345. /root/study-group/neural-networks-and-deep-learning/fig/regularized_full.json
# 346. /root/study-group/neural-networks-and-deep-learning/fig/regularized_full.png
#
# /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3
# 347. /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3/README.md
# 348. /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3/relu.png
# 349. /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3/relu.py
# 350. /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3/sigmoid.png
# 351. /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3/sigmoid.py
# 352. /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3/step.png
# 353. /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3/step.py
# 354. /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3/tanh.png
# 355. /root/study-group/neural-networks-and-deep-learning/fig/replaced_by_d3/tanh.py
# 356. /root/study-group/neural-networks-and-deep-learning/fig/serialize_images_to_json.py
# 357. /root/study-group/neural-networks-and-deep-learning/fig/test.png
# 358. /root/study-group/neural-networks-and-deep-learning/fig/training_speed_2_layers.png
# 359. /root/study-group/neural-networks-and-deep-learning/fig/training_speed_3_layers.png
# 360. /root/study-group/neural-networks-and-deep-learning/fig/training_speed_4_layers.png
# 361. /root/study-group/neural-networks-and-deep-learning/fig/valley.png
# 362. /root/study-group/neural-networks-and-deep-learning/fig/valley.py
# 363. /root/study-group/neural-networks-and-deep-learning/fig/valley2.png
# 364. /root/study-group/neural-networks-and-deep-learning/fig/valley2.py
# 365. /root/study-group/neural-networks-and-deep-learning/fig/weight_initialization.py
# 366. /root/study-group/neural-networks-and-deep-learning/fig/weight_initialization_100.json
# 367. /root/study-group/neural-networks-and-deep-learning/fig/weight_initialization_100.png
# 368. /root/study-group/neural-networks-and-deep-learning/fig/weight_initialization_30.json
# 369. /root/study-group/neural-networks-and-deep-learning/fig/weight_initialization_30.png
# 370. /root/study-group/neural-networks-and-deep-learning/requirements.txt
#
# /root/study-group/neural-networks-and-deep-learning/src
# 371. /root/study-group/neural-networks-and-deep-learning/src/conv.py
# 372. /root/study-group/neural-networks-and-deep-learning/src/expand_mnist.py
# 373. /root/study-group/neural-networks-and-deep-learning/src/mnist_average_darkness.py
# 374. /root/study-group/neural-networks-and-deep-learning/src/mnist_loader.py
# 375. /root/study-group/neural-networks-and-deep-learning/src/mnist_svm.py
# 376. /root/study-group/neural-networks-and-deep-learning/src/network.py
# 377. /root/study-group/neural-networks-and-deep-learning/src/network2.py
# 378. /root/study-group/neural-networks-and-deep-learning/src/network3.py
#
# /root/study-group/neural-networks-and-deep-learning/src/old
#
# /root/study-group/neural-networks-and-deep-learning/src/old/blog
# 379. /root/study-group/neural-networks-and-deep-learning/src/old/blog/__init__.py
# 380. /root/study-group/neural-networks-and-deep-learning/src/old/blog/common_knowledge.py
# 381. /root/study-group/neural-networks-and-deep-learning/src/old/cost_vs_iterations.png
# 382. /root/study-group/neural-networks-and-deep-learning/src/old/cost_vs_iterations_trapped.png
# 383. /root/study-group/neural-networks-and-deep-learning/src/old/deep_autoencoder.py
# 384. /root/study-group/neural-networks-and-deep-learning/src/old/deep_learning.py
# 385. /root/study-group/neural-networks-and-deep-learning/src/old/gradient_descent_hack.py
# 386. /root/study-group/neural-networks-and-deep-learning/src/old/mnist_100_30_deep_autoencoder.png
# 387. /root/study-group/neural-networks-and-deep-learning/src/old/mnist_100_unit_autoencoder.png
# 388. /root/study-group/neural-networks-and-deep-learning/src/old/mnist_10_unit_autoencoder.png
# 389. /root/study-group/neural-networks-and-deep-learning/src/old/mnist_30_component_pca.png
# 390. /root/study-group/neural-networks-and-deep-learning/src/old/mnist_30_unit_autoencoder.png
# 391. /root/study-group/neural-networks-and-deep-learning/src/old/mnist_autoencoder.py
# 392. /root/study-group/neural-networks-and-deep-learning/src/old/mnist_pca.py
# 393. /root/study-group/neural-networks-and-deep-learning/src/old/perceptron_learning.py
# 394. /root/study-group/neural-networks-and-deep-learning/src/run_network.ipynb
# 395. /root/study-group/neural-networks-and-deep-learning/src/run_network.py
#
# /root/study-group/nn-from-scratch
# 396. /root/study-group/nn-from-scratch/MNIST-loader.ipynb
# 397. /root/study-group/nn-from-scratch/MNIST-nn-SGD-flex_arch.ipynb
# 398. /root/study-group/nn-from-scratch/MNIST-nn-SGD.ipynb
# 399. /root/study-group/nn-from-scratch/MNIST-nn-scipy.ipynb
# 400. /root/study-group/nn-from-scratch/README.md
#
# /root/study-group/nn-from-scratch/data
#
# /root/study-group/nn-from-scratch/data/gzips
# 401. /root/study-group/nn-from-scratch/data/gzips/t10k-images-idx3-ubyte.gz
# 402. /root/study-group/nn-from-scratch/data/gzips/t10k-labels-idx1-ubyte.gz
# 403. /root/study-group/nn-from-scratch/data/gzips/train-images-idx3-ubyte.gz
# 404. /root/study-group/nn-from-scratch/data/gzips/train-labels-idx1-ubyte.gz
#
# /root/study-group/nn-from-scratch/data/pickled
# 405. /root/study-group/nn-from-scratch/data/pickled/xtest.pickle
# 406. /root/study-group/nn-from-scratch/data/pickled/xtrain.pickle
# 407. /root/study-group/nn-from-scratch/data/pickled/xval.pickle
# 408. /root/study-group/nn-from-scratch/data/pickled/ytest.pickle
# 409. /root/study-group/nn-from-scratch/data/pickled/ytrain.pickle
# 410. /root/study-group/nn-from-scratch/data/pickled/yval.pickle
#
# /root/study-group/slides
# 411. /root/study-group/slides/2017-02-07__katya_vasilaky__ridge_regression.pdf
# 412. /root/study-group/slides/2017-02-07__raphaela_sapire__billion_dollar_AI.pdf
# 413. /root/study-group/slides/2017-03-06__grant_beyleveld__u_net.pdf
#
# /root/study-group/weekly-work
#
# /root/study-group/weekly-work/week1
# 414. /root/study-group/weekly-work/week1/MNIST_for_beginners.ipynb
# 415. /root/study-group/weekly-work/week1/MNIST_for_beginners.py
# 416. /root/study-group/weekly-work/week1/README.md
# 417. /root/study-group/weekly-work/week1/basic_usage.ipynb
# 418. /root/study-group/weekly-work/week1/basic_usage.py
# 419. /root/study-group/weekly-work/week1/deep_MNIST.ipynb
# 420. /root/study-group/weekly-work/week1/deep_MNIST.py
# 421. /root/study-group/weekly-work/week1/exercise3.py
# 422. /root/study-group/weekly-work/week1/get_started.ipynb
# 423. /root/study-group/weekly-work/week1/get_started.py
# 424. /root/study-group/weekly-work/week1/softmax_vs_convolutional_nn.py
#
# /root/study-group/weekly-work/week2
# 425. /root/study-group/weekly-work/week2/MNIST_hierarchical_rnn.ipynb
# 426. /root/study-group/weekly-work/week2/README.md
# 427. /root/study-group/weekly-work/week2/getting_started_with_keras.ipynb
# 428. /root/study-group/weekly-work/week2/reuters_mlp.ipynb
#
# /root/study-group/weekly-work/week3
# 429. /root/study-group/weekly-work/week3/README.md
#
# /root/study-group/weekly-work/week4
# 430. /root/study-group/weekly-work/week4/README.md
#
# /root/study-group/weekly-work/week5
# 431. /root/study-group/weekly-work/week5/README.md
# 432. /root/study-group/weekly-work/week5/network3.ipynb
#
# /root/study-group/weekly-work/week6
# 433. /root/study-group/weekly-work/week6/README.md
#
# /root/study-group/weekly-work/week7
# 434. /root/study-group/weekly-work/week7/README.md
#
# /root/study-group/weekly-work/week8
# 435. /root/study-group/weekly-work/week8/README.md
#
# /root/study-group/weekly-work/week9
# 436. /root/study-group/weekly-work/week9/02_pros_and_cons_of_counting_vs_w2v.png
# 437. /root/study-group/weekly-work/week9/03_05_GloVe_visualizations_gender.png
# 438. /root/study-group/weekly-work/week9/03_06_GloVe_visualizations_CEO.png
# 439. /root/study-group/weekly-work/week9/03_07_GloVe_visualizations_superlatives.png
# 440. /root/study-group/weekly-work/week9/README.md
#
# /root/study-group/wiki-resources
# 441. /root/study-group/wiki-resources/gitflow.png
#
# /root/tf2
# 442. /root/tf2/LICENSE
# 443. /root/tf2/README.md
#
# /root/tf2/notebooks
# 444. /root/tf2/notebooks/deep_net.ipynb
# 445. /root/tf2/notebooks/deep_net_DEMO.ipynb
# 446. /root/tf2/notebooks/lenet.ipynb
# 447. /root/tf2/notebooks/lstm.ipynb
# 448. /root/tf2/notebooks/shallow_net.ipynb
# 449. /root/tf2/notebooks/shallow_net_DEMO.ipynb

# %%
pth = allFilesDict[1]
print(f'# %%writefile {pth.name}\n')
try:
    with open(pth, 'r') as openFile:
        print(openFile.read())
except:
    try:
        with open(pth, 'rb') as openFile:
            readLines = openFile.readlines()
            for line in readLines:
                print(f'{C.LITE}')
                print(line)
    except Exception as exc:
        print(exc)
        print(f'{C.RED}BULLSHIT')
# Out:
# # %%writefile README.md
#
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).
